# %% [markdown]
# # KUBiC Open API 사용자용 매뉴얼
# #### 작성자 : 한동 통일빅데이터센터 자료팀 신지영 RA (21800409@handong.edu)

# %% [markdown]
# # Open API 제공 데이터 및 서비스
# - 단순 검색(simple_search)
# - 상세 검색(detailed_search)
# - 내 보관함 내 검색(my_doc)

# %% [markdown]
# # 요청 변수 목록
# - 단순 검색(simple_search)
#
# |변수명(영문)|변수명(국문)|필수 여부|형식|샘플데이터|Default값(생략시)|
# |:------:|:---:|:---:|:---:|:---:|:---:|
# |serviceKey|인증키|Y|string| pP5JG2d-TZohr1sWMRVIwg |-|
# |numOfCnt|검색할 최대 개수|N|int|500|100|
# |rank|정렬기준|N|int|2(최신순)|1(정확도순)|
# |keyword|검색할 키워드|Y|string|북한|--|
#
# - 상세 검색(detailed_search) 또는 내 보관함 내 검색(my_doc)
#
# |변수명(영문)|변수명(국문)|필수 여부|형식|샘플데이터|Default값(생략시)|
# |:------:|:---:|:---:|:---:|:---:|:---:|
# |serviceKey|인증키|Y|string| pP5JG2d-TZohr1sWMRVIwg |-|
# |numOfCnt|검색할 최대 개수|N|int|500|100|
# |rank|정렬기준|N|int|2(최신순)|1(정확도순)|
# |keyword|검색할 키워드|N|string|북한|-|
# |keyInTitle|제목 내 검색할 키워드|Y|string|북한|-|
# |keyInBody|내용 내 검색할 키워드|N|string|정치|-|
# |writer|작성자 검색|N|string|홍길동|-|
# |startDate|작성일 기간시작점|N|YYYY-MM-DD|2018-09-17|현재로부터 2년 전|
# |endDate|작성일 기간끝점|N|YYYY-MM-DD|2020-09-17|현재 날짜|
# |institution|발행한 기관명|N|string|북한연구소|-|
# |category|분류|N|string|정치|-|

# %% [markdown]
# # 응답 변수 목록
#
# |변수명(영문)|변수명(국문)|
# |:-----:|:---:|
# |resultCode|결과 코드|
# |resultMSG|결과 메시지|
# |numOfContents|검색하려고 한 최대 개수|
# |totalCount|검색된 자료 개수|
# |rank|정렬 기준|
# |title|제목|
# |body|내용|
# |writer|작성자|
# |date|작성일|
# |originalURL|원본 문서 링크|
# |institution|발행 기관명|
# |institutionURL|발행 기관 링크|
# |category|분류|
# |fileName|파일 이름|
# |fileURL|첨부된 파일 링크|
# |fileContent|파일 문서 내용|

# %% [markdown]
# # 예제 코드
# ## 원하는 문서들을 불러와서 data frame에 띄우기

# %%
import urllib.request as r
import urllib.parse as p
import json
import pandas as pd

URL = "https://kubic.handong.edu:15000/"

# %% [markdown]
# ### 사용자에 맞게 수정할 부분

# %%
# 아래 부분 수정해주세요!
# 검색 옵션을 입력해주세요
## 단순검색=simple_search
## 상세검색=detailed_search
## 내 보관함 검색=my_doc
search_option="simple_search" #detailed_search #my_doc

# 인증키를 입력해주세요
serviceKey = "pP5JG2d-TZohr1sWMRVIwg"

# 한 번에 출력할 문서 개수를 입력해주세요
numOfCnt = 200

# 검색할 키워드를 입력해주세요
keyword="북한"

# %%
loginKey = "serviceKey="+serviceKey
request = "&numOfCnt="+p.quote(str(numOfCnt))+"&keyword="+p.quote(str(keyword))
URL_full = URL + search_option + "?" + loginKey + request

print("URL_full>" + URL_full)
response = r.urlopen(URL_full).read().decode('utf-8')

jsonArray = json.loads(response)

if jsonArray.get("header").get("resultCode") != 200:
    print("Error!!!")
    print(jsonArray.get("header"))
    quit()

items =jsonArray.get("body").get("contents")
# print("items>", items)
# Out:
# URL>https://kubic.handong.edu:15000/simple_search?serviceKey=pP5JG2d-TZohr1sWMRVIwg&numOfCnt=200&keyword=%EB%B6%81%ED%95%9C

# %%
df = pd.DataFrame(columns=['title','body','writer','date','category','institution','file'])
for item in items:
    df = df.append(item,ignore_index=True)
# print(df)

# %%
df
# Out:
#                                                  title  \
# 0           \r\n\t\t\t\t\t변하는 북한 변하지 않는 북한\r\n\t\t\t\t
# 1         \r\n\t\t\t\t\t북한 사람이 들려주는 북한 이야기\r\n\t\t\t\t
# 2    \r\n\t\t\t\t\t북한 주요인사 인물정보 2012 =북한 주요인물\r\n\t...
# 3    \r\n\t\t\t\t\t북한 주요인사 인물정보 2014 =북한 주요인물\r\n\t...
# 4                                   북한 핵실험 이후 북한 문제 해법
# ..                                                 ...
# 195                                남북한 경제통합과 북한 경제개발계획
# 196                                    북한 권력세습의 안정성 전망
# 197                                    2015년 북한 신년사 분석
# 198                                   북한 핵실험과 동북아 전략구도
# 199                                    2016년 북한 신년사 분석
#
#                                                   body               writer  \
# 0                                                 None                고정식 저
# 1                                                 None                장진성 저
# 2                                                 None  통일부 정세분석국 정치군사분석과 편
# 3                                                 None  통일부 정세분석국 정치군사분석과 편
# 4    제1세션: 대북정책 회고와 과제ㅇ 6.15 남북공동선언 어떻게 볼 것인가?/ 김영호...              통일연구원 편
# ..                                                 ...                  ...
# 195                                               None                  이석기
# 196  지난 9월 28일 북한 노동당대표자회는 김정은 후계구도가 공식화되는 자리였다. 이례...                  김진하
# 197  Ⅰ. 전반적 특징 ····································...       북한연구센터 신년사 분석팀
# 198                                               None                   조민
# 199  I. 전반적 특징 Ⅱ. 2015년도 평가 1. 총평2. 정치3. 경제4. 사회5. ...                김갑식 외
#
#            date                     category institution file  \
# 0          None                      통일부 발간물         통일부  NaN
# 1          None                      통일부 발간물         통일부  NaN
# 2          None                      통일부 발간물         통일부  NaN
# 3          None                      통일부 발간물         통일부  NaN
# 4          2009      \r\n\t\t연구보고서-기타연구보고서\n       통일연구원  NaN
# ..          ...                          ...         ...  ...
# 195        2006        \r\n\t\t현안분석-온라인시리즈\n       통일연구원  NaN
# 196  2010-10-27        \r\n\t\t현안분석-온라인시리즈\n       통일연구원  NaN
# 197        2015  \r\n\t\t현안분석-KINU Insight\n       통일연구원  NaN
# 198        2009        \r\n\t\t현안분석-온라인시리즈\n       통일연구원  NaN
# 199        2016  \r\n\t\t현안분석-KINU Insight\n       통일연구원  NaN
#
#                                               fileName  \
# 0           \r\n\t\t\t\t\t변하는 북한 변하지 않는 북한\r\n\t\t\t\t
# 1         \r\n\t\t\t\t\t북한 사람이 들려주는 북한 이야기\r\n\t\t\t\t
# 2    \r\n\t\t\t\t\t북한 주요인사 인물정보 2012 =북한 주요인물\r\n\t...
# 3    \r\n\t\t\t\t\t북한 주요인사 인물정보 2014 =북한 주요인물\r\n\t...
# 4                                   북한 핵실험 이후 북한 문제 해법
# ..                                                 ...
# 195                                남북한 경제통합과 북한 경제개발계획
# 196                                    북한 권력세습의 안정성 전망
# 197                                    2015년 북한 신년사 분석
# 198                                   북한 핵실험과 동북아 전략구도
# 199                                    2016년 북한 신년사 분석
#
#                                                fileURL  \
# 0    http://unibook.unikorea.go.kr/libeka/elec/WebB...
# 1    http://unibook.unikorea.go.kr/libeka/elec/WebB...
# 2    http://unibook.unikorea.go.kr/libeka/elec/WebB...
# 3    http://unibook.unikorea.go.kr/libeka/elec/WebB...
# 4    http://www.kinu.or.kr/pyxis-api/1/digital-file...
# ..                                                 ...
# 195  http://www.kinu.or.kr/pyxis-api/1/digital-file...
# 196  http://www.kinu.or.kr/pyxis-api/1/digital-file...
# 197  http://www.kinu.or.kr/pyxis-api/1/digital-file...
# 198  http://www.kinu.or.kr/pyxis-api/1/digital-file...
# 199  http://www.kinu.or.kr/pyxis-api/1/digital-file...
#
#                          institutionURL
# 0       https://unibook.unikorea.go.kr/
# 1       https://unibook.unikorea.go.kr/
# 2       https://unibook.unikorea.go.kr/
# 3       https://unibook.unikorea.go.kr/
# 4    http://www.kinu.or.kr/www/jsp/prg/
# ..                                  ...
# 195  http://www.kinu.or.kr/www/jsp/prg/
# 196  http://www.kinu.or.kr/www/jsp/prg/
# 197  http://www.kinu.or.kr/www/jsp/prg/
# 198  http://www.kinu.or.kr/www/jsp/prg/
# 199  http://www.kinu.or.kr/www/jsp/prg/
#
# [200 rows x 10 columns]
